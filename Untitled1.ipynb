# %%
# !pip install ultralytics

# %%
pip install torch

# %%
# !pip install roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LJJ0sALNd4Ljih7kSaoi")
project = rf.workspace("medical-isktt").project("detect_bsss")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6aedb067cab6> in <cell line: 4>()
#       2
#       3 from roboflow import Roboflow
# ----> 4 rf = Roboflow(api_key="LJJ0sALNd4Ljih7kSaoi")
#       5 project = rf.workspace("medical-isktt").project("detect_bsss")
#       6 version = project.version(5)
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     228         self.notebook = notebook
#     229         self.onboarding = False
# --> 230         self.auth()
#     231
#     232     def auth(self):
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in auth(self)
#     231
#     232     def auth(self):
# --> 233         r = check_key(self.api_key, self.model_format, self.notebook)
#     234
#     235         if r == "onboarding":
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/detect_bsss-3/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
